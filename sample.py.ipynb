# %%
lists=["Dhianeshwar","Divyadharshini","wedding"]
print(list)
# Out:
# ['Dhianeshwar', 'Divyadharshini', 'wedding']

# %%
names = ["Divya","Dhianesh", "Arun", "Nithi"]
print(names)
# Out:
# ['Divya', 'Dhianesh', 'Arun', 'Nithi']

# %%
names[0]="families"
print(names)
# Out:
# ['families', 'Dhianesh', 'Arun', 'Nithi']

# %%
names.append("Divya")
print(names)
# Out:
# ['families', 'Dhianesh', 'Arun', 'Nithi', 'Divya']

# %%
print(names)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 print(names)
#
# NameError: name 'names' is not defined

# %%
name = ["a","b","c","d"]
name.pop()
print(name)
# Out:
# ['a', 'b', 'c']

# %%
print(name.pop(0))
# Out:
# a

# %%
print(name)
# Out:
# ['b', 'c']

# %%
del name [0]
print(name)
# Out:
# ['c']
